# %%
from qiskit.visualization import plot_bloch_vector
import numpy as np

# %%
plot_bloch_vector([1,np.pi/2,np.pi/2], coord_type='spherical')

# %%
plot_bloch_vector([1,0,np.pi/2], coord_type='spherical',title='ket 0')

# %%
plot_bloch_vector([1,np.pi,0], coord_type='spherical', title='ket 1')

# %%
plot_bloch_vector([1,np.pi,0], coord_type='spherical', title='ket 1')
